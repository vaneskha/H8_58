# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in f:\anaconda\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in f:\anaconda\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in f:\anaconda\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in f:\anaconda\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in f:\anaconda\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0  1300.0000  1306.7233              H            L  0.640065   NaN
# 1  1300.0000  1293.2767              A            W  0.359935   NaN
# 2  1306.7233  1297.0712              H            W  0.631101   NaN
# 3  1300.0000  1309.6521              A            L  0.368899   NaN
# 4  1300.0000  1320.3811              H            L  0.640065   NaN
#
# [5 rows x 23 columns]

# %%
df.tail(2)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 126312   Warriors      105  1813.6349  1822.2881              H            L
# 126313  Cavaliers       97  1700.7391  1692.0859              A            W
#
#         forecast notes
# 126312   0.48145   NaN
# 126313   0.51855   NaN
#
# [2 rows x 23 columns]

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# 25%         0.000000      93.000000    1417.237975    1416.994900
# 50%         0.000000     103.000000    1500.945550    1500.954400
# 75%         0.000000     112.000000    1576.060000    1576.291625
# max         1.000000     186.000000    1853.104500    1853.104500
#
#            win_equiv        opp_pts      opp_elo_i      opp_elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean       41.707889     102.729982    1495.236055    1495.236055
# std        10.627332      14.814845     112.139945     112.461687
# min        10.152501       0.000000    1091.644500    1085.774400
# 25%        34.103035      93.000000    1417.237975    1416.994900
# 50%        42.113357     103.000000    1500.945550    1500.954400
# 75%        49.635328     112.000000    1576.060000    1576.291625
# max        71.112038     186.000000    1853.104500    1853.104500
#
#             forecast
# count  126314.000000
# mean        0.500000
# std         0.215252
# min         0.020447
# 25%         0.327989
# 50%         0.500000
# 75%         0.672011
# max         0.979553

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# DTF      60
# INJ      60
# TRH      60
# PIT      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
# dtypes: float64(6), int64(7), object(10)
# memory usage: 22.2+ MB

# %%
df[df['team_id']== 'MNL']
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1136        569  194811040BLB   NBA        1     1949   11/4/1948           1
# 1152        577  194811060WSC   NBA        1     1949   11/6/1948           2
# 1159        580  194811090BOS   NBA        1     1949   11/9/1948           3
# 1170        586  194811110NYK   NBA        1     1949  11/11/1948           4
# 1183        592  194811130PRO   NBA        1     1949  11/13/1948           5
# ...         ...           ...   ...      ...      ...         ...         ...
# 9701       4851  196003190LAL   NBA        0     1960   3/19/1960          80
# 9702       4852  196003200LAL   NBA        0     1960   3/20/1960          81
# 9709       4855  196003220STL   NBA        1     1960   3/22/1960          82
# 9711       4856  196003240LAL   NBA        0     1960   3/24/1960          83
# 9715       4858  196003260STL   NBA        1     1960   3/26/1960          84
#
#       is_playoffs team_id fran_id  ...  win_equiv  opp_id      opp_fran  \
# 1136            0     MNL  Lakers  ...  51.218754     BLB     Baltimore
# 1152            0     MNL  Lakers  ...  50.621624     WSC      Capitols
# 1159            0     MNL  Lakers  ...  48.341133     BOS       Celtics
# 1170            0     MNL  Lakers  ...  49.499451     NYK        Knicks
# 1183            0     MNL  Lakers  ...  50.330185     PRO  Steamrollers
# ...           ...     ...     ...  ...        ...     ...           ...
# 9701            1     MNL  Lakers  ...  36.052319     STL         Hawks
# 9702            1     MNL  Lakers  ...  36.565147     STL         Hawks
# 9709            1     MNL  Lakers  ...  38.137211     STL         Hawks
# 9711            1     MNL  Lakers  ...  36.154404     STL         Hawks
# 9715            1     MNL  Lakers  ...  35.694744     STL         Hawks
#
#       opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast  \
# 1136       72  1507.2052  1491.9507              A            W  0.386583
# 1152       67  1481.8721  1487.9188              A            L  0.443232
# 1159       77  1359.3345  1382.0542              A            L  0.608859
# 1170       68  1460.4232  1448.9517              A            W  0.432863
# 1183       67  1245.9456  1237.6326              A            W  0.737010
# ...       ...        ...        ...            ...          ...       ...
# 9701       93  1564.9653  1571.4325              H            L  0.508790
# 9702      101  1571.4325  1566.4786              H            W  0.490179
# 9709      110  1566.4786  1551.3701              A            W  0.243506
# 9711      117  1551.3701  1570.4452              H            L  0.547775
# 9715       97  1570.4452  1574.8955              A            L  0.235193
#
#      notes
# 1136   NaN
# 1152   NaN
# 1159   NaN
# 1170   NaN
# 1183   NaN
# ...    ...
# 9701   NaN
# 9702   NaN
# 9709   NaN
# 9711   NaN
# 9715   NaN
#
# [946 rows x 23 columns]

# %%
df.loc[df["fran_id"] == "Lakers", "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df["team_id"]== "MNL", "date_game"].min()
# Out:
# '1/1/1949'

# %%
df.loc[df["team_id"]== "MNL", "date_game"].max()
# Out:
# '4/9/1959'

# %%
df.loc[df["team_id"]== "MNL", "date_game"].agg(('min', 'max'))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
df.loc[df["team_id"] == "MNL", "pts"].sum()
# Out:
# 88229

# %%
rev = pd.Series([5555, 7000, 1980])
rev
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=["Amsterdam", "Toronto", "Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count

city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_employee_count[1]
# Out:
# 8

# %%
colors = pd.Series(
    ["red", "purple", "blue", "green", "yellow"],
    index=[1, 2, 3, 5, 8]
)

# %%
colors.loc[1]
# Out:
# 'red'

# %%
colors.iloc[1]
# Out:
# 'purple'

# %%
city_data.loc["Amsterdam"]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.iloc[1]
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %%
city_data["revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
games_with_notes = df[df["notes"].notnull()]
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# 930             28            0     WSC      Capitols  ...  47.065742     BLB
# 931             31            0     BLB     Baltimore  ...  46.407490     WSC
# 1084            49            1     WSC      Capitols  ...  47.710297     CHS
# 1085            49            1     CHS         Stags  ...  46.089687     WSC
# 1088            49            1     BLB     Baltimore  ...  50.044666     CHS
# ...            ...          ...     ...           ...  ...        ...     ...
# 122207          39            0     ATL         Hawks  ...  39.239410     BRK
# 123916           8            0     HOU       Rockets  ...  54.894760     MIN
# 123917           7            0     MIN  Timberwolves  ...  40.129723     HOU
# 124862          40            0     MIL         Bucks  ...  41.138866     NYK
# 124863          41            0     NYK        Knicks  ...  21.189493     MIL
#
#             opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  \
# 930        Baltimore       95  1434.0548  1448.5005              A
# 931         Capitols       71  1469.3469  1454.9012              H
# 1084           Stags       74  1440.7186  1445.4203              A
# 1085        Capitols       70  1465.9006  1461.1990              H
# 1088           Stags       72  1445.4203  1438.3618              A
# ...              ...      ...        ...        ...            ...
# 122207          Nets      127  1454.6501  1472.1118              N
# 123916  Timberwolves      101  1502.9229  1496.2412              N
# 123917       Rockets      113  1635.7723  1642.4540              N
# 124862        Knicks       79  1304.4620  1298.5029              N
# 124863         Bucks       95  1499.9038  1505.8629              N
#
#         game_result  forecast                                      notes
# 930               L  0.407940       at Baltimore's Fifth Regiment Armory
# 931               W  0.592060       at Baltimore's Fifth Regiment Armory
# 1084              L  0.393962                                 Tiebreaker
# 1085              W  0.606038                                 Tiebreaker
# 1088              W  0.403142                                 Tiebreaker
# ...             ...       ...                                        ...
# 122207            L  0.572030                         at London, England
# 123916            W  0.682383  at Mexico City Arena, Mexico City, Mexico
# 123917            L  0.317617  at Mexico City Arena, Mexico City, Mexico
# 124862            W  0.754925                 at The O2, London, England
# 124863            L  0.245075                 at The O2, London, England
#
# [5424 rows x 23 columns]

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] < 100) &
    (df["team_id"] == "MNL") |
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 701         351  194711120WSC   NBA        1     1948  11/12/1947           1
# 702         352  194711130BLB   NBA        0     1948  11/13/1947           2
# 714         358  194711150CHS   NBA        1     1948  11/15/1947           3
# 729         365  194711200BLB   NBA        0     1948  11/20/1947           4
# 737         369  194711210BOS   NBA        1     1948  11/21/1947           5
# ...         ...           ...   ...      ...      ...         ...         ...
# 9180       4591  195911200LAL   NBA        0     1960  11/20/1959          15
# 9391       4696  196001090LAL   NBA        0     1960    1/9/1960          38
# 9594       4798  196002210LAL   NBA        0     1960   2/21/1960          62
# 9625       4813  196002270LAL   NBA        0     1960   2/27/1960          68
# 9684       4843  196003130LAL   NBA        0     1960   3/13/1960          77
#
#       is_playoffs team_id    fran_id  ...  win_equiv  opp_id  opp_fran  \
# 701             0     BLB  Baltimore  ...  42.867378     WSC  Capitols
# 702             0     BLB  Baltimore  ...  43.288319     BOS   Celtics
# 714             0     BLB  Baltimore  ...  44.263027     CHS     Stags
# 729             0     BLB  Baltimore  ...  44.906929     NYK    Knicks
# 737             0     BLB  Baltimore  ...  46.179226     BOS   Celtics
# ...           ...     ...        ...  ...        ...     ...       ...
# 9180            0     MNL     Lakers  ...  36.334961     DET   Pistons
# 9391            0     MNL     Lakers  ...  30.893564     CIN     Kings
# 9594            0     MNL     Lakers  ...  28.510260     STL     Hawks
# 9625            0     MNL     Lakers  ...  32.062023     PHW  Warriors
# 9684            1     MNL     Lakers  ...  35.533512     DET   Pistons
#
#       opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast  \
# 701        63  1481.0703  1485.6085              A            L  0.282326
# 702        74  1289.9966  1285.9733              H            W  0.784507
# 714        63  1439.0546  1429.7191              A            W  0.333132
# 729        56  1378.5894  1372.4034              H            W  0.702461
# 737        73  1298.5594  1286.2784              A            W  0.550836
# ...       ...        ...        ...            ...          ...       ...
# 9180       85  1473.9630  1462.1300              H            W  0.615242
# 9391       91  1378.0790  1364.9020              H            W  0.669175
# 9594       98  1594.0540  1574.8754              H            W  0.328508
# 9625       91  1636.8563  1613.4728              H            W  0.315149
# 9684       99  1417.4689  1409.7950              H            W  0.684360
#
#                   notes
# 701                 NaN
# 702                 NaN
# 714                 NaN
# 729                 NaN
# 737                 NaN
# ...                 ...
# 9180                NaN
# 9391                NaN
# 9594  at Los Angeles CA
# 9625                NaN
# 9684                NaN
#
# [525 rows x 23 columns]

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("LA")) &
    (df["year_id"] == 1992) &
    (df["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  ...  win_equiv  opp_id      opp_fran  \
# 68901            1     LAC  Clippers  ...  47.888252     UTA          Jazz
# 68903            1     LAL    Lakers  ...  39.395412     POR  Trailblazers
#
#        opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast  \
# 68901      107  1647.5092  1638.4095              H            W  0.499125
# 68903      102  1655.1210  1670.3677              H            L  0.406874
#
#                                             notes
# 68901  at Anaheim, CA (Anaheim Convention Center)
# 68903                            at Las Vegas, NV
#
# [2 rows x 23 columns]

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
df.sort_values(by=['col1']).groupby("fran_id", sort=True)['pts'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-5019a8fbaeb5> in <module>
# ----> 1 df.sort_values(by=['col1']).groupby("fran_id", sort=True)['pts'].sum()
#
# F:\Anaconda\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5453
#    5454             by = by[0]
# -> 5455             k = self._get_label_or_level_values(by, axis=axis)
#    5456
#    5457             # need to rewrap column in Series to apply key function
#
# F:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'col1'

# %%
nba = df.copy()
nba["date_game"] = pd.to_datetime(nba["date_game"])

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
#  17  opp_elo_i      126314 non-null  float64
#  18  opp_elo_n      126314 non-null  float64
#  19  game_location  126314 non-null  object
#  20  game_result    126314 non-null  object
#  21  forecast       126314 non-null  float64
#  22  notes          5424 non-null    object
# dtypes: datetime64[ns](1), float64(6), int64(7), object(9)
# memory usage: 22.2+ MB

# %%
nba["game_location"].nunique()
# Out:
# 3

# %%
data_without_missing_columns = nba.dropna(axis=1)

# %%
data_without_missing_columns.shape
# Out:
# (126314, 22)

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  \
# 26684            0     DNR  Nuggets  ...  40.408863     VIR   Squires
#
#        opp_pts  opp_elo_i opp_elo_n  game_location  game_result  forecast  \
# 26684        2  1484.1907  1487.083              A            L  0.328948
#
#                                 notes
# 26684  at Richmond VA; forfeit to VIR
#
# [1 rows x 23 columns]

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')].empty
# Out:
# True

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count": [2, 2]},
    index=["New York", "Barcelona"]
)
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1, 1, 0, 0, 0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)
all_city_data = pd.concat([city_data, further_city_data], sort=False)
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
# %matplotlib inline
nba[nba["fran_id"] == "Lakers"].groupby("year_id")["pts"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>
